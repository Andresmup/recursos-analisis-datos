# %% [markdown]
# <a href="https://colab.research.google.com/github/Andresmup/recursos-analisis-datos/blob/dev/12_Pandas_2/Clase12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CLASE 12

# %% [markdown]
# ## PANDAS DATAFRAME
#
# Un dataframe es similar a una hoja de cálculo donde cada fila representa un registro y cada columna es una característica o atributo de esos registros.
#
# Cada una de esta filas de forma individual seria una Serie

# %% [markdown]
# ### Ejercicio 1.0
#
# Instalacion e importacion

# %%
# !pip install pandas==2.2.2
# Out:
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# Successfully installed pandas-2.2.2

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Ejercicio 1.1
#
# Creacion Dataframe

# %%
#Podemos crear un dataframe a partir de listas

lista_p1 = ["Andres", "Muñoz", 26, True]
lista_p2 = ["Esteban", "Domiguez", 43, False]
lista_p3 = ["Maria", "Chesti", 32, True]
lista_p4 = ["Marcela", "Kisfe", 19, False]

lista_encabezados = ["Nombre","Apellido","Edad","Aprobado"]

df_personas = pd.DataFrame(data=[lista_p1, lista_p2, lista_p3, lista_p4], columns = lista_encabezados)
df_personas
# Out:
#     Nombre  Apellido  Edad  Aprobado
# 0   Andres     Muñoz    26      True
# 1  Esteban  Domiguez    43     False
# 2    Maria    Chesti    32      True
# 3  Marcela     Kisfe    19     False

# %%
#Otra opcion muy comun es crear un Dataframe a partir de un diccionario

diccionario_empleados = {
  "Nombre":["Andres","Sofia","Mercedes","Pablo"],
  "Apellido":["Muñoz","Cerves","Garcia","Alaves"],
  "Sueldo":[4500,6000,2300,5300],
  "Facturacion":[True,False,True,True]
}
diccionario_empleados
# Out:
# {'Nombre': ['Andres', 'Sofia', 'Mercedes', 'Pablo'],
#  'Apellido': ['Muñoz', 'Cerves', 'Garcia', 'Alaves'],
#  'Sueldo': [4500, 6000, 2300, 5300],
#  'Facturacion': [True, False, True, True]}

# %%
df_empleados = pd.DataFrame(diccionario_empleados)
df_empleados
# Out:
#      Nombre Apellido  Sueldo  Facturacion
# 0    Andres    Muñoz    4500         True
# 1     Sofia   Cerves    6000        False
# 2  Mercedes   Garcia    2300         True
# 3     Pablo   Alaves    5300         True

# %%
#Podemos importar los datos desde un array y crear un dataframe

rng = np.random.default_rng()

# %%
array_6x3 = rng.integers(1,20,(6,3))
print(array_6x3)
# Out:
# [[17 17  1]
#  [12 18  8]
#  [ 2  9  9]
#  [11  9  9]
#  [13 14 15]
#  [15 18 16]]

# %%
lista_nombre_encabezados = ["clientes_uni","cantidad_kg","ingresos_mil_usd"]

df_resumen_ventas = pd.DataFrame(data=array_6x3, columns=lista_nombre_encabezados)
df_resumen_ventas
# Out:
#    clientes_uni  cantidad_kg  ingresos_mil_usd
# 0            17           17                 1
# 1            12           18                 8
# 2             2            9                 9
# 3            11            9                 9
# 4            13           14                15
# 5            15           18                16

# %% [markdown]
# ### Ejercicio 1.2
#
# Podemos trabajar con los indices tal como hicimos con las Series anteriormente

# %%
lista_patentes = ["12-AFS-2524","45-LKS-1284","94-KAN-9381","84-UWA-9012"]

lista_v1 = ["Ford","Focus",3000,True]
lista_v2 = ["Toyota","Hilux",10000,True]
lista_v3 = ["Ford","F-100",2000,False]
lista_v4 = ["Renault","Cactus",3500,True]


lista_columnas_encabezados = ["marca","modelo","valor","0KM"]

df_vehiculos = pd.DataFrame(data=[lista_v1,lista_v2,lista_v3,lista_v4], index=lista_patentes, columns=lista_columnas_encabezados)
df_vehiculos
# Out:
#                marca  modelo  valor    0KM
# 12-AFS-2524     Ford   Focus   3000   True
# 45-LKS-1284   Toyota   Hilux  10000   True
# 94-KAN-9381     Ford   F-100   2000  False
# 84-UWA-9012  Renault  Cactus   3500   True

# %%
#Otra opcion es usar el metodo set index

diccionario_empleados = {
  "ID":["F-001","C-001","F-002","F-003","F-004","C-002"],
  "Nombre":["Andres","Sofia","Mercedes","Pablo","Claudia","Miguel"],
  "Apellido":["Muñoz","Cerves","Garcia","Alaves","Perez","Solis"],
  "Sueldo":[4500,6000,2300,5300,4920,5000],
  "Departamento":["IT","Sales","IT","IT","HR","Sales"],
  "Facturacion":[True,True,False,True,True,False]
}

df_empleados = pd.DataFrame(diccionario_empleados)
df_empleados
# Out:
#       ID    Nombre Apellido  Sueldo Departamento  Facturacion
# 0  F-001    Andres    Muñoz    4500           IT         True
# 1  C-001     Sofia   Cerves    6000        Sales         True
# 2  F-002  Mercedes   Garcia    2300           IT        False
# 3  F-003     Pablo   Alaves    5300           IT         True
# 4  F-004   Claudia    Perez    4920           HR         True
# 5  C-002    Miguel    Solis    5000        Sales        False

# %%
df_empleados.set_index('ID', inplace=True)
df_empleados
# Out:
#          Nombre Apellido  Sueldo Departamento  Facturacion
# ID
# F-001    Andres    Muñoz    4500           IT         True
# C-001     Sofia   Cerves    6000        Sales         True
# F-002  Mercedes   Garcia    2300           IT        False
# F-003     Pablo   Alaves    5300           IT         True
# F-004   Claudia    Perez    4920           HR         True
# C-002    Miguel    Solis    5000        Sales        False

# %%
# El indice pueden ser fechas

dias = pd.date_range(start='2024-01-01', end='2024-04-17')

df_resumen_ventas = pd.DataFrame(
    data = {
        "nro_ventas":rng.integers(10,50,len(dias)),
        "ganancia":rng.random(len(dias)).round(2),
        "ingresos_mil_usd":rng.integers(100,2000,len(dias))
    },
    index=dias)
df_resumen_ventas
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-01          19      0.15              1545
# 2024-01-02          44      0.15              1925
# 2024-01-03          28      0.53               102
# 2024-01-04          33      0.64               375
# 2024-01-05          30      0.08              1667
# ...                ...       ...               ...
# 2024-04-13          10      0.82               863
# 2024-04-14          19      0.08               841
# 2024-04-15          13      0.81              1883
# 2024-04-16          32      0.64              1391
# 2024-04-17          37      0.66              1218
#
# [108 rows x 3 columns]

# %% [markdown]
# ### Ejercicio 1.3
#
# Repaso metodos importantes que sirven para trabajar con dataframes

# %%
df_resumen_ventas.head(7) #Head nos trae los primeros N elementos
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-01          19      0.15              1545
# 2024-01-02          44      0.15              1925
# 2024-01-03          28      0.53               102
# 2024-01-04          33      0.64               375
# 2024-01-05          30      0.08              1667
# 2024-01-06          30      0.99               819
# 2024-01-07          32      0.54              1515

# %%
df_resumen_ventas.tail() #Tail trae los ultimos N elementos, el valor por defecto es 5
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-04-13          10      0.82               863
# 2024-04-14          19      0.08               841
# 2024-04-15          13      0.81              1883
# 2024-04-16          32      0.64              1391
# 2024-04-17          37      0.66              1218

# %%
df_resumen_ventas.describe() #Uso describe
# Out:
#        nro_ventas    ganancia  ingresos_mil_usd
# count  108.000000  108.000000        108.000000
# mean    28.731481    0.460926       1004.518519
# std     11.612599    0.301078        563.437339
# min     10.000000    0.000000        102.000000
# 25%     17.750000    0.180000        462.750000
# 50%     30.000000    0.390000       1050.000000
# 75%     38.250000    0.715000       1458.750000
# max     49.000000    0.990000       1978.000000

# %%
df_resumen_ventas.shape #Tenemos 108 filas por 2 columnas
# Out:
# (108, 3)

# %%
df_resumen_ventas.nro_ventas #Aislo un columna -> Serie
# Out:
# 2024-01-01    19
# 2024-01-02    44
# 2024-01-03    28
# 2024-01-04    33
# 2024-01-05    30
#               ..
# 2024-04-13    10
# 2024-04-14    19
# 2024-04-15    13
# 2024-04-16    32
# 2024-04-17    37
# Freq: D, Name: nro_ventas, Length: 108, dtype: int64

# %%
df_resumen_ventas[df_resumen_ventas.ingresos_mil_usd > 1800] #Puedo filtrar mi dataframe aplicandole una regla a una columna (Series)
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-02          44      0.15              1925
# 2024-01-21          20      0.62              1978
# 2024-01-23          34      0.22              1811
# 2024-01-26          35      0.36              1967
# 2024-02-14          44      0.11              1873
# 2024-02-15          33      0.40              1961
# 2024-02-20          31      0.97              1805
# 2024-02-21          43      0.14              1951
# 2024-02-27          44      0.68              1839
# 2024-03-11          36      0.92              1886
# 2024-04-15          13      0.81              1883

# %%
df_resumen_ventas[(df_resumen_ventas.nro_ventas > 40) & (df_resumen_ventas.ingresos_mil_usd > 1500)] #Podemos concatenar diferentes reglas
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-02          44      0.15              1925
# 2024-01-10          47      0.12              1720
# 2024-02-14          44      0.11              1873
# 2024-02-21          43      0.14              1951
# 2024-02-27          44      0.68              1839
# 2024-03-18          48      0.16              1665
# 2024-04-05          46      0.14              1710
# 2024-04-08          42      0.11              1612

# %%
df_resumen_ventas.iloc[0] #Obtenemos el primer elemento
# Out:
# nro_ventas            19.00
# ganancia               0.15
# ingresos_mil_usd    1545.00
# Name: 2024-01-01 00:00:00, dtype: float64

# %%
df_resumen_ventas.iloc[3] #Obtenemos el cuarto elemento
# Out:
# nro_ventas           33.00
# ganancia              0.64
# ingresos_mil_usd    375.00
# Name: 2024-01-04 00:00:00, dtype: float64

# %%
df_resumen_ventas.iloc[-1] #Ultimo elemento
# Out:
# nro_ventas            37.00
# ganancia               0.66
# ingresos_mil_usd    1218.00
# Name: 2024-04-17 00:00:00, dtype: float64

# %%
df_resumen_ventas.iloc[4:10] #Filtrado desde la posicion 4 (incluida) hasta la 10(excluida)
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-05          30      0.08              1667
# 2024-01-06          30      0.99               819
# 2024-01-07          32      0.54              1515
# 2024-01-08          25      0.68               580
# 2024-01-09          20      0.09              1375
# 2024-01-10          47      0.12              1720

# %%
df_resumen_ventas.iloc[:9] #El filtrado termina en 9 elemento
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-01          19      0.15              1545
# 2024-01-02          44      0.15              1925
# 2024-01-03          28      0.53               102
# 2024-01-04          33      0.64               375
# 2024-01-05          30      0.08              1667
# 2024-01-06          30      0.99               819
# 2024-01-07          32      0.54              1515
# 2024-01-08          25      0.68               580
# 2024-01-09          20      0.09              1375

# %%
df_resumen_ventas.iloc[-15:] #El filtrado inicia desde el -15 adelante
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-04-03          42      0.96              1440
# 2024-04-04          25      0.49              1224
# 2024-04-05          46      0.14              1710
# 2024-04-06          10      0.78               182
# 2024-04-07          45      0.11              1327
# 2024-04-08          42      0.11              1612
# 2024-04-09          29      0.93               206
# 2024-04-10          27      0.29               508
# 2024-04-11          33      0.53               800
# 2024-04-12          11      0.34               144
# 2024-04-13          10      0.82               863
# 2024-04-14          19      0.08               841
# 2024-04-15          13      0.81              1883
# 2024-04-16          32      0.64              1391
# 2024-04-17          37      0.66              1218

# %%
df_resumen_ventas.sort_values(by="ganancia") #Ordenamos de menor a mayor nuestro dataframe en funcion de la ganancia
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-03-03          22      0.00               342
# 2024-03-02          47      0.01              1085
# 2024-01-17          25      0.02               465
# 2024-01-16          13      0.05               444
# 2024-04-02          29      0.06               331
# ...                ...       ...               ...
# 2024-03-30          17      0.96              1308
# 2024-02-20          31      0.97              1805
# 2024-03-26          20      0.97              1531
# 2024-03-31          36      0.97              1226
# 2024-01-06          30      0.99               819
#
# [108 rows x 3 columns]

# %%
df_resumen_ventas.sort_values(by="ingresos_mil_usd",ascending = False) #Ordenamos de mayor a menor nuestro dataframe en funcion de ingresos_mil_usd
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-21          20      0.62              1978
# 2024-01-26          35      0.36              1967
# 2024-02-15          33      0.40              1961
# 2024-02-21          43      0.14              1951
# 2024-01-02          44      0.15              1925
# ...                ...       ...               ...
# 2024-03-06          46      0.46               177
# 2024-03-16          16      0.73               159
# 2024-04-12          11      0.34               144
# 2024-03-17          33      0.90               125
# 2024-01-03          28      0.53               102
#
# [108 rows x 3 columns]

# %%
dict_concesionaria = {
    'marca': ['Ford','Toyota','Audi','Ford','Ford','Renault','Chevrolet','Ford','Ford','Volkswagen','Honda','BMW','Mercedes-Benz','Ford','Ford'],
    'modelo': ['Focus','Hilux','A3','Mustang','F-100','Cactus','Spark','Escape','Explorer','Gol','Civic','X5','Clase C','Ranger','Fusion'],
    'precio': [3000,10000,10000,20000,2000,3500,4000,18000,25000,6000,8000,15000,12000,22000,17000],
    '0Km': [True,True,True,True,False,True,False,True,False,True,True,True,False,True,False]
  }

df_concesionaria = pd.DataFrame(dict_concesionaria)
df_concesionaria
# Out:
#             marca    modelo  precio    0Km
# 0            Ford     Focus    3000   True
# 1          Toyota     Hilux   10000   True
# 2            Audi        A3   10000   True
# 3            Ford   Mustang   20000   True
# 4            Ford     F-100    2000  False
# 5         Renault    Cactus    3500   True
# 6       Chevrolet     Spark    4000  False
# 7            Ford    Escape   18000   True
# 8            Ford  Explorer   25000  False
# 9      Volkswagen       Gol    6000   True
# 10          Honda     Civic    8000   True
# 11            BMW        X5   15000   True
# 12  Mercedes-Benz   Clase C   12000  False
# 13           Ford    Ranger   22000   True
# 14           Ford    Fusion   17000  False

# %%
#Podemos aplicar multiples condiciones que incluyan strings, booleanos e integers

df_concesionaria[(df_concesionaria.marca == "Ford") & (df_concesionaria["precio"] > 10000) & (df_concesionaria["0Km"] == True)] #Podemos aplicar la busqueda usando los corchetes y pasando el nombre de la columna
# Out:
#    marca   modelo  precio   0Km
# 3   Ford  Mustang   20000  True
# 7   Ford   Escape   18000  True
# 13  Ford   Ranger   22000  True

# %% [markdown]
# ### Ejercicio 1.4
#
# Los dataframes son editables podemos cambiar aspectos como:

# %%
df_concesionaria
# Out:
#             marca    modelo  precio    0Km
# 0            Ford     Focus    3000   True
# 1          Toyota     Hilux   10000   True
# 2            Audi        A3   10000   True
# 3            Ford   Mustang   20000   True
# 4            Ford     F-100    2000  False
# 5         Renault    Cactus    3500   True
# 6       Chevrolet     Spark    4000  False
# 7            Ford    Escape   18000   True
# 8            Ford  Explorer   25000  False
# 9      Volkswagen       Gol    6000   True
# 10          Honda     Civic    8000   True
# 11            BMW        X5   15000   True
# 12  Mercedes-Benz   Clase C   12000  False
# 13           Ford    Ranger   22000   True
# 14           Ford    Fusion   17000  False

# %%
#Si queremos renombrar una columna debemos aplicar

nuevas_columnas = {
    "marca":"MARCA",
    "modelo":"NOMBRE",
    "precio":"PRECIO_USD",
    "0Km":"UNICO_DUENO"
}

df_concesionaria.rename(columns=nuevas_columnas, inplace=True)

# %%
df_concesionaria
# Out:
#             MARCA    NOMBRE  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
#PODEMOS CAMBIAR EL NOMBRE DE UNA COLUMNA UNICAMENTE

df_concesionaria.rename(columns={"MARCA":"MODELO"}, inplace=True)

df_concesionaria
# Out:
#            MODELO    NOMBRE  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
#Podemos aplicar/renombrar nuestro indice generado por defecto

df_concesionaria.index.rename(name="ID",inplace=True)

df_concesionaria
# Out:
#            MODELO    NOMBRE  PRECIO_USD  UNICO_DUENO
# ID
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
df_resumen_ventas.head()
# Out:
#             nro_ventas  ganancia  ingresos_mil_usd
# 2024-01-01          19      0.15              1545
# 2024-01-02          44      0.15              1925
# 2024-01-03          28      0.53               102
# 2024-01-04          33      0.64               375
# 2024-01-05          30      0.08              1667

# %%
df_resumen_ventas.index.rename(name="dia",inplace=True)
df_resumen_ventas.rename(columns={"ganancia":"ganancia_%"},inplace=True)
df_resumen_ventas
# Out:
#             nro_ventas  ganancia_%  ingresos_mil_usd
# dia
# 2024-01-01          19        0.15              1545
# 2024-01-02          44        0.15              1925
# 2024-01-03          28        0.53               102
# 2024-01-04          33        0.64               375
# 2024-01-05          30        0.08              1667
# ...                ...         ...               ...
# 2024-04-13          10        0.82               863
# 2024-04-14          19        0.08               841
# 2024-04-15          13        0.81              1883
# 2024-04-16          32        0.64              1391
# 2024-04-17          37        0.66              1218
#
# [108 rows x 3 columns]

# %% [markdown]
# ### Ejercicio 1.5
#
# Veamos como concatenar o agregar elemenos a un dataframe

# %%
df_concesionaria.rename(columns={"MODELO":"MARCA","NOMBRE":"MODELO"}, inplace=True)
df_concesionaria #Tenemos nuestro dataframe
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# ID
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
df_concesionaria.shape #Que tiene la cantidad de 15 filas y 4 columnas
# Out:
# (15, 4)

# %%
#Añado una nueva fila

nuevo_vehiculo = pd.DataFrame(data=[
      ["Fiat","Sienna",1000,False]
    ],
    columns=["MARCA","MODELO","PRECIO_USD","UNICO_DUENO"]
)

pd.concat([df_concesionaria, nuevo_vehiculo])
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False
# 0            Fiat    Sienna        1000        False

# %%
#Puedo "sobreescribir" para tener todos los vehiculos en este dataframe

df_concesionaria = pd.concat([df_concesionaria, nuevo_vehiculo],ignore_index=True) #Ignoramos el indice para que nuevo_vehiculo tenga un indice que continue con los numeros previos

df_concesionaria
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False
# 15           Fiat    Sienna        1000        False

# %%
df_concesionaria.shape #Ahora tiene 18 filas
# Out:
# (16, 4)

# %%
#Podemos agregar varios filas a la vez

vehiculos_importados = pd.DataFrame(data={
    'MARCA': ['Porche','Bugati','Chevrolet'],
    'MODELO': ['Cayen','Veiron','Camaro'],
    'PRECIO_USD': [31000,900000,100000],
    'UNICO_DUENO': [True,True,True]
  }
)

df_concesionaria = pd.concat([df_concesionaria, vehiculos_importados],ignore_index=True)

df_concesionaria
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False
# 15           Fiat    Sienna        1000        False
# 16         Porche     Cayen       31000         True
# 17         Bugati    Veiron      900000         True
# 18      Chevrolet    Camaro      100000         True

# %%
df_concesionaria.shape #Veamos como cambio la cantidad de filas y columnas
# Out:
# (19, 4)

# %%
#Tenemos que tener mucha precaucion ya que si no coinciden las columnas los valores se van a agregar generando nuevas columnas

vehiculos_importados = pd.DataFrame(data={
    'fabricante': ['Porche','Bugati','Chevrolet'],
    'modelo': ['Cayen','Veiron','Camaro'],
    'costo': [31000,900000,100000],
    '0km': [True,True,True]
  }
)

df_concesionaria_2 = pd.concat([df_concesionaria, vehiculos_importados],ignore_index=True)

df_concesionaria_2
# Out:
#             MARCA    MODELO  PRECIO_USD UNICO_DUENO fabricante  modelo  \
# 0            Ford     Focus      3000.0        True        NaN     NaN
# 1          Toyota     Hilux     10000.0        True        NaN     NaN
# 2            Audi        A3     10000.0        True        NaN     NaN
# 3            Ford   Mustang     20000.0        True        NaN     NaN
# 4            Ford     F-100      2000.0       False        NaN     NaN
# 5         Renault    Cactus      3500.0        True        NaN     NaN
# 6       Chevrolet     Spark      4000.0       False        NaN     NaN
# 7            Ford    Escape     18000.0        True        NaN     NaN
# 8            Ford  Explorer     25000.0       False        NaN     NaN
# 9      Volkswagen       Gol      6000.0        True        NaN     NaN
# 10          Honda     Civic      8000.0        True        NaN     NaN
# 11            BMW        X5     15000.0        True        NaN     NaN
# 12  Mercedes-Benz   Clase C     12000.0       False        NaN     NaN
# 13           Ford    Ranger     22000.0        True        NaN     NaN
# 14           Ford    Fusion     17000.0       False        NaN     NaN
# 15           Fiat    Sienna      1000.0       False        NaN     NaN
# 16         Porche     Cayen     31000.0        True        NaN     NaN
# 17         Bugati    Veiron    900000.0        True        NaN     NaN
# 18      Chevrolet    Camaro    100000.0        True        NaN     NaN
# 19            NaN       NaN         NaN         NaN     Porche   Cayen
# 20            NaN       NaN         NaN         NaN     Bugati  Veiron
# 21            NaN       NaN         NaN         NaN  Chevrolet  Camaro
#
#        costo   0km
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# 5        NaN   NaN
# 6        NaN   NaN
# 7        NaN   NaN
# 8        NaN   NaN
# 9        NaN   NaN
# 10       NaN   NaN
# 11       NaN   NaN
# 12       NaN   NaN
# 13       NaN   NaN
# 14       NaN   NaN
# 15       NaN   NaN
# 16       NaN   NaN
# 17       NaN   NaN
# 18       NaN   NaN
# 19   31000.0  True
# 20  900000.0  True
# 21  100000.0  True

# %%
df_concesionaria_2.shape #Vemos que ahora se duplicaron la cantidad de columnas
# Out:
# (22, 8)

# %% [markdown]
# ### Ejercicio 1.6
#
# Con los dataframe hay otra opcion muy usada y es el merge

# %%
df_empleados_cobro = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Sueldo': [5000, 6000, 4500, 5500],
    'Facturacion': [True, True, False, True],
    'Antiguedad': [3, 5, 2, 8]
})

df_empleados_info = pd.DataFrame({
    'ID': [101, 102, 105, 106],
    'Edad': [31, 36, 29, 41],
    'Cargo': ['Analista', 'Gerente', 'Analista', 'Director'],
    'Nombre':["Pedro","Camila",'Mariano','Federico']
})

# %%
df_empleados_cobro
# Out:
#     ID  Sueldo  Facturacion  Antiguedad
# 0  101    5000         True           3
# 1  102    6000         True           5
# 2  103    4500        False           2
# 3  104    5500         True           8

# %%
df_empleados_info
# Out:
#     ID  Edad     Cargo    Nombre
# 0  101    31  Analista     Pedro
# 1  102    36   Gerente    Camila
# 2  105    29  Analista   Mariano
# 3  106    41  Director  Federico

# %%
#Left merge
df_left_merge = pd.merge(df_empleados_cobro,df_empleados_info,how="left",on='ID')
df_left_merge
# Out:
#     ID  Sueldo  Facturacion  Antiguedad  Edad     Cargo  Nombre
# 0  101    5000         True           3  31.0  Analista   Pedro
# 1  102    6000         True           5  36.0   Gerente  Camila
# 2  103    4500        False           2   NaN       NaN     NaN
# 3  104    5500         True           8   NaN       NaN     NaN

# %%
#Right merge (join sql)
df_right_merge = pd.merge(df_empleados_cobro,df_empleados_info,how="right",on='ID')
df_right_merge
# Out:
#     ID  Sueldo Facturacion  Antiguedad  Edad     Cargo    Nombre
# 0  101  5000.0        True         3.0    31  Analista     Pedro
# 1  102  6000.0        True         5.0    36   Gerente    Camila
# 2  105     NaN         NaN         NaN    29  Analista   Mariano
# 3  106     NaN         NaN         NaN    41  Director  Federico

# %%
df_empleados = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Sueldo': [5000, 6000, 4500, 5500],
    'Edad': [30, 35, 28, 40],
    'Cargo': ['Analista', 'Gerente', 'Analista', 'Director'],
    'Facturacion': [True, True, False, True],
    'Antiguedad': [3, 5, 2, 8],
    'Departamento_ID':[1,2,4,3]
})
df_departamentos = pd.DataFrame({
    'Departamento_ID':[1,2,3],
    'Nombre':["Sales","IT","HR"],
    'Piso':[1,2,2],
    'Rotacion_24hs':[True,True,False]
})

# %%
df_empleados
# Out:
#     ID  Sueldo  Edad     Cargo  Facturacion  Antiguedad  Departamento_ID
# 0  101    5000    30  Analista         True           3                1
# 1  102    6000    35   Gerente         True           5                2
# 2  103    4500    28  Analista        False           2                4
# 3  104    5500    40  Director         True           8                3

# %%
df_departamentos
# Out:
#    Departamento_ID Nombre  Piso  Rotacion_24hs
# 0                1  Sales     1           True
# 1                2     IT     2           True
# 2                3     HR     2          False

# %%
#Inner merge
df_inner_merge = pd.merge(df_empleados,df_departamentos,how="inner",on="Departamento_ID")
df_inner_merge
# Out:
#     ID  Sueldo  Edad     Cargo  Facturacion  Antiguedad  Departamento_ID  \
# 0  101    5000    30  Analista         True           3                1
# 1  102    6000    35   Gerente         True           5                2
# 2  104    5500    40  Director         True           8                3
#
#   Nombre  Piso  Rotacion_24hs
# 0  Sales     1           True
# 1     IT     2           True
# 2     HR     2          False

# %%
#Outer merge
df_outer_merge = pd.merge(df_empleados,df_departamentos,how="outer",on="Departamento_ID")
df_outer_merge
# Out:
#     ID  Sueldo  Edad     Cargo  Facturacion  Antiguedad  Departamento_ID  \
# 0  101    5000    30  Analista         True           3                1
# 1  102    6000    35   Gerente         True           5                2
# 2  104    5500    40  Director         True           8                3
# 3  103    4500    28  Analista        False           2                4
#
#   Nombre  Piso Rotacion_24hs
# 0  Sales   1.0          True
# 1     IT   2.0          True
# 2     HR   2.0         False
# 3    NaN   NaN           NaN

# %% [markdown]
# ### Ejercicio 1.7
#
# En pandas podemos trabajar con los nulos, los cuales son valores faltantes o informacion perdida

# %%
semana = pd.date_range(start='2024-04-08', end='2024-04-14')

df_resumen_ventas = pd.DataFrame(
    data = {
        "clientes":[10,np.nan,12,16,20,np.nan,14],
        "pedidos":[4,2,14,10,1,10,12],
        "ingresos":[np.nan,20000,4500,7000,np.nan,5900,12000]
    },
    index=semana)
df_resumen_ventas
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4       NaN
# 2024-04-09       NaN        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1       NaN
# 2024-04-13       NaN       10    5900.0
# 2024-04-14      14.0       12   12000.0

# %%
#Vemos que valores son nulos
df_resumen_ventas.isnull()
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08     False    False      True
# 2024-04-09      True    False     False
# 2024-04-10     False    False     False
# 2024-04-11     False    False     False
# 2024-04-12     False    False      True
# 2024-04-13      True    False     False
# 2024-04-14     False    False     False

# %%
#Calculo de cuantas filas contienen nulos
df_resumen_ventas.isnull().sum()
# Out:
# clientes    2
# pedidos     0
# ingresos    2
# dtype: int64

# %%
#Deja solo las filas sin nulos
df_resumen_ventas.dropna()
# Out:
#             clientes  pedidos  ingresos
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-14      14.0       12   12000.0

# %%
#Deja solo las columnas sin nulos
df_resumen_ventas.dropna(axis=1)
# Out:
#             pedidos
# 2024-04-08        4
# 2024-04-09        2
# 2024-04-10       14
# 2024-04-11       10
# 2024-04-12        1
# 2024-04-13       10
# 2024-04-14       12

# %%
# Rellenar los valores nulos con 0
df_resumen_ventas.fillna(0)
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4       0.0
# 2024-04-09       0.0        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1       0.0
# 2024-04-13       0.0       10    5900.0
# 2024-04-14      14.0       12   12000.0

# %%
df_resumen_ventas.median()
# Out:
# clientes      14.0
# pedidos       10.0
# ingresos    7000.0
# dtype: float64

# %%
#Reemplaza la media con la media de cada columna
df_resumen_ventas.fillna(df_resumen_ventas.median())
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4    7000.0
# 2024-04-09      14.0        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1    7000.0
# 2024-04-13      14.0       10    5900.0
# 2024-04-14      14.0       12   12000.0

# %%
#Se puede interpolar, aunque solo es recomendable cuando matematicamente la operacion tiene sentido
df_resumen_ventas.interpolate()
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4       NaN
# 2024-04-09      11.0        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1    6450.0
# 2024-04-13      17.0       10    5900.0
# 2024-04-14      14.0       12   12000.0
